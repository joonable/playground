# %%
from itertools import chain
import pandas as pd

# %%
colours = [["회색","그래이","그레이"],
["빨강","레드","빨간","적색"],
["노랑","노란","옐로","옐로우"],
["카키","캬키"],
["분홍","핑크"],
["하늘색","소라색"],
["흰색","백색","하얀","화이트"],
["갈색","브라운","부라운"],
["남색","네이비","곤색"],
["베이지","배이지"],
["보라","퍼플","바이올렛","바이올랫","바이올릿","바이올렉","바이오렛"],
["검정","블랙","검은","블렉","흑색"],
["파랑","블루","파란"],
["와인색","버건디"],
["카멜","캐멀","캬멜"],
["초록","그린","녹색"]]

suffix_list = ["색","색깔","색상","칼라","컬러"]

# %%
colour_dict_list = []
for colour in chain(*colours):
    for suffix in suffix_list:
        colour_dict_list.append(colour + suffix + " " + colour + " " + suffix)
colour_dict_list
# Out:
# ['회색색 회색 색',
#  '회색색깔 회색 색깔',
#  '회색색상 회색 색상',
#  '회색칼라 회색 칼라',
#  '회색컬러 회색 컬러',
#  '그래이색 그래이 색',
#  '그래이색깔 그래이 색깔',
#  '그래이색상 그래이 색상',
#  '그래이칼라 그래이 칼라',
#  '그래이컬러 그래이 컬러',
#  '그레이색 그레이 색',
#  '그레이색깔 그레이 색깔',
#  '그레이색상 그레이 색상',
#  '그레이칼라 그레이 칼라',
#  '그레이컬러 그레이 컬러',
#  '빨강색 빨강 색',
#  '빨강색깔 빨강 색깔',
#  '빨강색상 빨강 색상',
#  '빨강칼라 빨강 칼라',
#  '빨강컬러 빨강 컬러',
#  '레드색 레드 색',
#  '레드색깔 레드 색깔',
#  '레드색상 레드 색상',
#  '레드칼라 레드 칼라',
#  '레드컬러 레드 컬러',
#  '빨간색 빨간 색',
#  '빨간색깔 빨간 색깔',
#  '빨간색상 빨간 색상',
#  '빨간칼라 빨간 칼라',
#  '빨간컬러 빨간 컬러',
#  '적색색 적색 색',
#  '적색색깔 적색 색깔',
#  '적색색상 적색 색상',
#  '적색칼라 적색 칼라',
#  '적색컬러 적색 컬러',
#  '노랑색 노랑 색',
#  '노랑색깔 노랑 색깔',
#  '노랑색상 노랑 색상',
#  '노랑칼라 노랑 칼라',
#  '노랑컬러 노랑 컬러',
#  '노란색 노란 색',
#  '노란색깔 노란 색깔',
#  '노란색상 노란 색상',
#  '노란칼라 노란 칼라',
#  '노란컬러 노란 컬러',
#  '옐로색 옐로 색',
#  '옐로색깔 옐로 색깔',
#  '옐로색상 옐로 색상',
#  '옐로칼라 옐로 칼라',
#  '옐로컬러 옐로 컬러',
#  '옐로우색 옐로우 색',
#  '옐로우색깔 옐로우 색깔',
#  '옐로우색상 옐로우 색상',
#  '옐로우칼라 옐로우 칼라',
#  '옐로우컬러 옐로우 컬러',
#  '카키색 카키 색',
#  '카키색깔 카키 색깔',
#  '카키색상 카키 색상',
# ...

# %%
sr_colour = pd.Series(colour_dict_list)

# %%
dt='20190130'
sr_colour.to_csv('/home/admin-/PycharmProjects/playground/synonyms_from_category/data/colour_user_dict_'+dt+'.csv', index=False)

# %%
any_dict = {
    "schema": {
        "type": "struct",
        "fields": [
            {
                "type": "bytes",
                "optional": False,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "MESSAGE_ID"
            },
            {
                "type": "string",
                "optional": True,
                "field": "DBSTS"
            },
            {
                "type": "string",
                "optional": False,
                "field": "BBS_ID"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "MESSAGE_LEVEL"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PARENT_MESSAGE_ID"
            },
            {
                "type": "bytes",
                "optional": False,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "ECUSERID"
            },
            {
                "type": "string",
                "optional": True,
                "field": "TITLE"
            },
            {
                "type": "string",
                "optional": True,
                "field": "NICK_NAME"
            },
            {
                "type": "string",
                "optional": True,
                "field": "IP_ADDRESS"
            },
            {
                "type": "string",
                "optional": True,
                "field": "AGE_LIMIT_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "REPORT_FLAG"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "LSECTID"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "MSECTID"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "RPST_PRDID"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PRDID"
            },
            {
                "type": "string",
                "optional": True,
                "field": "PRDNAME"
            },
            {
                "type": "string",
                "optional": True,
                "field": "BUYER_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "MESSAGE_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "CONTENTS_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "SMS_FLAG"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PRDID2"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PRDID3"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PRDID4"
            },
            {
                "type": "string",
                "optional": True,
                "field": "URGENT_FLAG"
            },
            {
                "type": "int64",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Timestamp",
                "version": 1,
                "field": "START_DATE"
            },
            {
                "type": "int64",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Timestamp",
                "version": 1,
                "field": "END_DATE"
            },
            {
                "type": "string",
                "optional": True,
                "field": "CHOICE_FLAG"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "CHOICE_PRDID"
            },
            {
                "type": "int64",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Timestamp",
                "version": 1,
                "field": "CHOICE_DATE"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PRD_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "REPLY_ADOPT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PRD_SATISFACT"
            },
            {
                "type": "string",
                "optional": True,
                "field": "EVAL_NAME1"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "EVAL_VALUE1"
            },
            {
                "type": "string",
                "optional": True,
                "field": "EVAL_NAME2"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "EVAL_VALUE2"
            },
            {
                "type": "string",
                "optional": True,
                "field": "EVAL_NAME3"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "EVAL_VALUE3"
            },
            {
                "type": "string",
                "optional": True,
                "field": "EVAL_NAME4"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "EVAL_VALUE4"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "READ_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PARTICIPANT_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "OPPOSITION_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "REPLY_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "BUYER_REPLY_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "COMMENT_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "SCRAP_COUNT"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "POINT"
            },
            {
                "type": "string",
                "optional": True,
                "field": "REMARK"
            },
            {
                "type": "string",
                "optional": True,
                "field": "INDEX_COLUMN"
            },
            {
                "type": "string",
                "optional": True,
                "field": "CREUSER"
            },
            {
                "type": "int64",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Timestamp",
                "version": 1,
                "field": "CREDATE"
            },
            {
                "type": "string",
                "optional": True,
                "field": "UPDUSER"
            },
            {
                "type": "int64",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Timestamp",
                "version": 1,
                "field": "UPDDATE"
            },
            {
                "type": "string",
                "optional": True,
                "field": "GUBUN"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "AGE"
            },
            {
                "type": "string",
                "optional": True,
                "field": "SUB_NAME"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "ORDNUM"
            },
            {
                "type": "string",
                "optional": True,
                "field": "RPST_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "ORD_OPTION1_NM"
            },
            {
                "type": "string",
                "optional": True,
                "field": "ORD_OPTION2_NM"
            },
            {
                "type": "string",
                "optional": True,
                "field": "ORD_OPTION3_NM"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "YEAR_SALE_POINT"
            },
            {
                "type": "string",
                "optional": True,
                "field": "SAVE_ROOT"
            },
            {
                "type": "string",
                "optional": True,
                "field": "CUS_GRADE"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "DSCR_BYTES"
            },
            {
                "type": "string",
                "optional": True,
                "field": "ORD_OPTION_DISP_YN"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "BEST_YEAR_SALE_POINT"
            },
            {
                "type": "string",
                "optional": True,
                "field": "BEST_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "BEST_CHOICEUSER"
            },
            {
                "type": "int64",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Timestamp",
                "version": 1,
                "field": "BEST_CHOICEDATE"
            },
            {
                "type": "string",
                "optional": True,
                "field": "FILE_STS"
            },
            {
                "type": "bytes",
                "optional": True,
                "name": "org.apache.kafka.connect.data.Decimal",
                "version": 1,
                "parameters": {
                    "scale": "0"
                },
                "field": "PROMO_NUM"
            },
            {
                "type": "string",
                "optional": True,
                "field": "IMAGE_LIMIT_FLAG"
            },
            {
                "type": "string",
                "optional": True,
                "field": "CHANL_CD"
            }
        ],
        "optional": False,
        "name": "GS_KNOW_MESSAGE"
    },
    "payload": {
        "MESSAGE_ID": "B/rOHg==",
        "DBSTS": "A",
        "BBS_ID": "estimate",
        "MESSAGE_LEVEL": "AQ==",
        "PARENT_MESSAGE_ID": None,
        "ECUSERID": "d35MMA==",
        "TITLE": "잘가지고 놀아요~물고 놀기에도 좋아요",
        "NICK_NAME": "codk*****",
        "IP_ADDRESS": "112.168.0.117",
        "AGE_LIMIT_FLAG": "N",
        "REPORT_FLAG": None,
        "LSECTID": "FQn3",
        "MSECTID": "FQt7",
        "RPST_PRDID": None,
        "PRDID": "AdEjYg==",
        "PRDNAME": "[딩동펫]애견장난감 간식장난감 모래시계S",
        "BUYER_FLAG": "Y",
        "MESSAGE_FLAG": None,
        "CONTENTS_FLAG": "1",
        "SMS_FLAG": None,
        "PRDID2": None,
        "PRDID3": None,
        "PRDID4": None,
        "URGENT_FLAG": None,
        "START_DATE": None,
        "END_DATE": None,
        "CHOICE_FLAG": None,
        "CHOICE_PRDID": None,
        "CHOICE_DATE": None,
        "PRD_COUNT": None,
        "REPLY_ADOPT": None,
        "PRD_SATISFACT": "ZA==",
        "EVAL_NAME1": "디자인",
        "EVAL_VALUE1": "BQ==",
        "EVAL_NAME2": "품질",
        "EVAL_VALUE2": "BQ==",
        "EVAL_NAME3": "배송",
        "EVAL_VALUE3": "BQ==",
        "EVAL_NAME4": "사용만족도",
        "EVAL_VALUE4": "BQ==",
        "READ_COUNT": "AA==",
        "PARTICIPANT_COUNT": "AA==",
        "OPPOSITION_COUNT": "AA==",
        "REPLY_COUNT": "AA==",
        "BUYER_REPLY_COUNT": "AA==",
        "COMMENT_COUNT": "AA==",
        "SCRAP_COUNT": "AA==",
        "POINT": "Mg==",
        "REMARK": "N",
        "INDEX_COLUMN": "1",
        "CREUSER": "2004765744",
        "CREDATE": 1540497101000,
        "UPDUSER": "system",
        "UPDDATE": 1540497102000,
        "GUBUN": None,
        "AGE": None,
        "SUB_NAME": None,
        "ORDNUM": "NwpYig==",
        "RPST_FLAG": None,
        "ORD_OPTION1_NM": None,
        "ORD_OPTION2_NM": None,
        "ORD_OPTION3_NM": None,
        "YEAR_SALE_POINT": "AA==",
        "SAVE_ROOT": "mobilePrd",
        "CUS_GRADE": "DD",
        "DSCR_BYTES": "NA==",
        "ORD_OPTION_DISP_YN": "Y",
        "BEST_YEAR_SALE_POINT": None,
        "BEST_FLAG": None,
        "BEST_CHOICEUSER": None,
        "BEST_CHOICEDATE": None,
        "FILE_STS": None,
        "PROMO_NUM": None,
        "IMAGE_LIMIT_FLAG": None,
        "CHANL_CD": "B"
    }
}

# %%
keys = list(any_dict['payload'].keys())

# %%
vals = list(any_dict['payload'].values())

# %%
import pandas as pd

# %%
df = pd.DataFrame(index=keys, columns=['val', 'type', 'name'])

# %%
schema = any_dict['schema']['fields']

# %%
df['val'] = vals

for field_info in schema:
    df.loc[field_info['field'], 'type'] = field_info['type']
    df.loc[field_info['field'], 'name'] = field_info.get('name', None)

# %%
df.loc['TITLE', :]
# Out:
# val     잘가지고 놀아요~물고 놀기에도 좋아요
# type                  string
# name                    None
# Name: TITLE, dtype: object

# %%
len(vals)
# Out:
# 75

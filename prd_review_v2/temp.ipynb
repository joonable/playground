# %%
import pandas as pd

# %%
data_dir = '../prd_review_v2/data/'

# %%
df = pd.read_pickle(data_dir+'df_dataset.pkl')

# %%
token = '팩'
df[token] = df.x.apply(lambda x: True if token in x else False)

# %%
df.loc[df[token] == True, ['text', 'x']].sample(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6585</th>
#       <td>견미리팩트 화장할때마다 정말 좋다는 생각이 들고 매시즌 신상 구입해서 딸과 잘 쓰고...</td>
#       <td>[견미리, 팩, 트, 화장, 때, 정말, 좋, 생각, 듣, 매, 시즌, 신상, 구입...</td>
#     </tr>
#     <tr>
#       <th>363582</th>
#       <td>받자마자 아침에 무료체험용 으로 사용했는데 개인적이지만 많이 건조해요 에센스함량이 ...</td>
#       <td>[받, 아침, 무료, 체험, 사용, 개인, 많이, 건조, 에센스, 함량, 많, 쿠션...</td>
#     </tr>
#     <tr>
#       <th>323554</th>
#       <td>일에 주문하고 일날 도착했습니다 배송 정말 빨라요 😲끈적거림도 없고 흡수도 너무 ...</td>
#       <td>[6, 일, 주문, 8, 일, 날, 도착, 배송, 정말, 빠르, 😲, 끈적거리, 없...</td>
#     </tr>
#     <tr>
#       <th>119662</th>
#       <td>견미리팩트만 몇년째 계속 재구매합니다 제 피부에 딱 맞고 건조한 피부인데 항상 촉촉해요</td>
#       <td>[견미리, 팩, 트, 몇, 년, 계속, 구매, 저, 피부, 딱, 맞, 건조, 피부,...</td>
#     </tr>
#     <tr>
#       <th>197003</th>
#       <td>견미리 팩트 구입은 벌써 번째 구입해서 사용하고 있어요 민감한 피부에 지성피부여서 ...</td>
#       <td>[견미리, 팩, 트, 구입, 벌써, 4, 번, 구입, 사용, 있, 민감, 피부, 지...</td>
#     </tr>
#     <tr>
#       <th>774797</th>
#       <td>인생팩을 만났어요 좀 비싼감은 있지만 겨울철 건조함을 잡기위해 이틀에 한번씩 팩합니...</td>
#       <td>[인생, 팩, 만나, 좀, 비싸, 감, 있, 겨울, 철, 건조, 잡, 위하, 이틀,...</td>
#     </tr>
#     <tr>
#       <th>582661</th>
#       <td>전부터 눈이 자꾸가던 베리떼로 팩트라는것을 처음으로 사봅니다 너무 이쁘네요</td>
#       <td>[전, 눈, 자꾸, 갈, 베리, 떼, 팩, 틀, 것, 처음, 사, 보, 너무, 이쁘]</td>
#     </tr>
#     <tr>
#       <th>115922</th>
#       <td>엄마랑 동생이랑 늘 이것만 써요 인생팩트에요♡</td>
#       <td>[엄마, 동생, 늘, 이거, 쓰, 인생, 팩, 틀]</td>
#     </tr>
#     <tr>
#       <th>184888</th>
#       <td>시즌 기다리다 드뎌 주문 ㅎ 케이스 넘 이뻐요 구성도 좋고 피부좋다는 얘기 들어 기...</td>
#       <td>[시즌, 기다리, 들, 뎌, 주문, ㅎ, 케이스, 넘, 이쁘, 구성, 좋, 피부, ...</td>
#     </tr>
#     <tr>
#       <th>508232</th>
#       <td>창밖의 날씨는 비도 내리고 우울한 분위기 인데 엄청 빠른 배송에 기분도 활짝 예전 ...</td>
#       <td>[창, 밖, 날씨, 비, 내리, 우울, 분위기, 엄청, 빠르, 배송, 기분, 활짝,...</td>
#     </tr>
#     <tr>
#       <th>51981</th>
#       <td>다른것 사서 사용해보다가 돌아돌아서 결국은 다시 age팩트를 쓰게 되네요 대후반 이...</td>
#       <td>[다른, 것, 살, 사용, 보, 돌, 돌, 결국, 다시, age, 팩, 트, 쓸, ...</td>
#     </tr>
#     <tr>
#       <th>372895</th>
#       <td>시즌 부터 지금까지 계속 사용하고 있어요 다른 제품으로 바꿀 수 없게 만드는 나에게...</td>
#       <td>[시즌, 1, 지금, 계속, 사용, 있, 다른, 제품, 바꾸, 수, 없, 만들, 나...</td>
#     </tr>
#     <tr>
#       <th>18783</th>
#       <td>제품 잘받았구요 믿고 얼굴에 예쁘게 바르겠습니다 좋은제품 감사합니다 이런엣센스 커버...</td>
#       <td>[제품, 잘, 받, 믿, 얼굴, 예쁘, 바르, 좋, 제품, 감사, 이런, 엣, 센스...</td>
#     </tr>
#     <tr>
#       <th>488300</th>
#       <td>제품이 떨어져서 미바를 구입해서 써봤는데 맘에들지않아 반품하고 다시 견미리팩트구입하...</td>
#       <td>[제품, 떨어지, 미, 바르, 구입, 쓰, 보, 맘, 듣, 않, 반품, 다시, 견미...</td>
#     </tr>
#     <tr>
#       <th>2830</th>
#       <td>아주 촉촉하고 좋습니다 커버력은 좀 떨어지는데 얼굴이 화사해지고 특별한 트러블 없는...</td>
#       <td>[아주, 촉촉, 좋, 크, 버력, 좀, 떨어지, 얼굴, 화사, 지, 특별, 트러블,...</td>
#     </tr>
#     <tr>
#       <th>50143</th>
#       <td>저렴한 가격에 팩이나주니 넘좋아요</td>
#       <td>[저렴, 가격, 3, 팩, 주니, 넘, 좋]</td>
#     </tr>
#     <tr>
#       <th>276288</th>
#       <td>빠른배송 좋구요 평소에 화장을 잘 안하던 저인데 요 팩트를 만나고부턴 화장도 자주 ...</td>
#       <td>[빠르, 배송, 좋, 평소, 화장, 잘, 안, 하, 제, 팩, 트, 만나, 화장, ...</td>
#     </tr>
#     <tr>
#       <th>382742</th>
#       <td>벌써 년째 이용하는 에이지투웨니스 커버팩트네요 ㅋ 매번 변화가 있었어도 잘 몰랐는데...</td>
#       <td>[벌써, 3, 년, 이용, 에이, 지, 투, 웨, 니스, 커버, 팩, 틀, ㅋㅋ, ...</td>
#     </tr>
#     <tr>
#       <th>741565</th>
#       <td>매시즌마다 구입해 만족하며 사용하고있어요 촉촉하고 들뜨지않고 언제 어느때나 톡톡 두...</td>
#       <td>[매, 시즌, 구입, 만족, 사용, 있, 촉촉, 들뜨, 않, 언제, 어느, 때, 톡...</td>
#     </tr>
#     <tr>
#       <th>635925</th>
#       <td>늘 쓰는 팩트 신상으로 구매했어요 아직 써보진 않았지만 좋기를 기대하며 상품평씁니다</td>
#       <td>[늘, 쓸, 팩, 트, 신상, 구매, 아직, 쓰, 보, 않, 좋, 기대, 상, 품평...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.loc[df[token] == True, ['text', 'x']].sample(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>x</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>631934</th>
#       <td>빨래 두 번만에 다 뜯어져서 버렸습니다 에공 망에 집어 넣었어야 했는데 ㅠ 씁쓸합니다</td>
#       <td>[빨래, 두, 번, 만, 다, 뜯, 지, 버리, 에, 공, 망, 집, 넣, 하, 씁쓸]</td>
#     </tr>
#     <tr>
#       <th>408038</th>
#       <td>초등학생 학년 남아 아이 입으려공 구입했는데오 잘맞공 이쁘네오</td>
#       <td>[초등, 학생, 5, 학년, 남, 아이, 입, 공, 구입, 오, 잘, 공, 이쁘, 오]</td>
#     </tr>
#     <tr>
#       <th>512171</th>
#       <td>새로운 뉴 에이지 케이스도 예쁘공퍼프또한 넘 귀엽네요 몇년째 쓰는 제품이라 믿고 사...</td>
#       <td>[새롭, 뉴, 에이지, 케이스, 예쁘, 공, 퍼프, 또한, 넘, 귀엽, 몇, 년, ...</td>
#     </tr>
#     <tr>
#       <th>231604</th>
#       <td>남녀 공용인가요 옷이 많이 커요 입으면 핏이 예쁠 것이고 이면 이너로 두꺼운 옷입는...</td>
#       <td>[남녀, 공용, 옷, 많이, 크, 85, 입, 핏, 예쁘, 것, 90, 이너, 두껍...</td>
#     </tr>
#     <tr>
#       <th>713566</th>
#       <td>샤워하고 한번씩 밀어주면 욕실에 습기도 빨리 없어지고 쾌적해지는거같아요 창문이 없어...</td>
#       <td>[샤워, 한, 번, 밀, 주, 욕실, 습기, 빨리, 없, 지, 쾌적, 지, 것, 같...</td>
#     </tr>
#     <tr>
#       <th>301129</th>
#       <td>엄지와 새끼손가락 다낄수있어 만족하고 딸랑딸랑하니 포인트도되공 다른반지랑 달라서좋아...</td>
#       <td>[엄지, 새끼, 손, 가락, 다, 끼, 수, 있, 만족, 딸랑딸랑, 하, 포인트, ...</td>
#     </tr>
#     <tr>
#       <th>223591</th>
#       <td>이번시즌 또 해냈군요 땡기는것 없고 끼임도 없공 정말 실망을 안해서 넘좋아요</td>
#       <td>[이, 번, 시즌, 또, 해내, 땡기, 것, 없, 끼, 없, 공, 정말, 실망, 안...</td>
#     </tr>
#     <tr>
#       <th>640450</th>
#       <td>와우 넘넘 좋아요 이불빨래도 바로 해서 덮을수있공 애기옷 먼지 안날리고 굿굿 신세계...</td>
#       <td>[와우, 넘, 넘, 좋, 이, 빨래, 바로, 하, 덮, 수, 있, 공, 애기, 옷,...</td>
#     </tr>
#     <tr>
#       <th>94848</th>
#       <td>정말정말따뜻하고좋아요 먼지많이나는구스이불보다좋아요 구스이불샀다가공청기빨간불몇날며칠을...</td>
#       <td>[정말, 정말, 따뜻, 좋, 먼지, 많이, 나, 구스, 이불, 좋, 구스, 이불, ...</td>
#     </tr>
#     <tr>
#       <th>334942</th>
#       <td>로션사용중인데 이제 추워진 날씨에 우리 아기 피부 건조하지말라공 구입했는데 정말 좋...</td>
#       <td>[로션, 사용, 중, 이제, 춥, 지, 날씨, 우리, 아기, 피부, 건조, 말, 공...</td>
#     </tr>
#     <tr>
#       <th>529758</th>
#       <td>넘좋아요 다른 립밤 많이 썼는데 진짜요게 젤좋아요 향도좋고 가격도싸공</td>
#       <td>[넘, 좋, 다른, 립, 밤, 많이, 쓰, 진짜, 요거, 젤, 좋, 향, 좋, 가격...</td>
#     </tr>
#     <tr>
#       <th>351953</th>
#       <td>와 완전 득템했어요 그레이 xs했는데 두껍지 않은 니트 입고 약간 여유 있어요 완전...</td>
#       <td>[완전, 득템, 167, 54, 그레이, xs, 두껍, 않, 니트, 입, 약간, 여...</td>
#     </tr>
#     <tr>
#       <th>724354</th>
#       <td>좋아용 항상 잘쓰고 있는 제품입니다 최공</td>
#       <td>[좋, 항상, 잘, 쓸, 있, 제품, 공]</td>
#     </tr>
#     <tr>
#       <th>619888</th>
#       <td>립밥 사은품 많이오공ㅎ 립밥색두이쁘공ㅎ</td>
#       <td>[립, 밥, 1, 1, 사은, 품, 많이, 오공, ㅎ, 립, 밥, 색, 이쁘, 공, ㅎ]</td>
#     </tr>
#     <tr>
#       <th>749082</th>
#       <td>아주 만족스러워요 사이즈도 좋네요 하나 더 사려고 타공바구니 없는 것으로 찾고 있어요</td>
#       <td>[아주, 만족, 사이즈, 좋, 하나, 더, 살, 타, 공, 바구니, 없, 것, 찾, 있]</td>
#     </tr>
#     <tr>
#       <th>519059</th>
#       <td>피치기모래서 샀는데 좀 얇은듯해요 편하게 입으려공ᆢ</td>
#       <td>[피치, 기모, 사, 좀, 얇, 듯, 편하, 입, 공]</td>
#     </tr>
#     <tr>
#       <th>62388</th>
#       <td>에공 제가 살이 빠진것두 아닐터인데 저에게 좀 큰걸요 허리 부분이 낙낙하네요</td>
#       <td>[에, 공, 제, 살, 빠지, 것, 터, 제, 좀, 크, 것, 허리, 부분, 낙낙]</td>
#     </tr>
#     <tr>
#       <th>172567</th>
#       <td>마이 크네용 줄이는 것도 없공</td>
#       <td>[마이, 크, 줄이, 것, 없, 공]</td>
#     </tr>
#     <tr>
#       <th>76158</th>
#       <td>보기에는 좁아서 공이 들어갈까 했는데 적당하고 딱 좋네요</td>
#       <td>[보, 좁, 공, 들어가, 하, 적당, 딱, 좋]</td>
#     </tr>
#     <tr>
#       <th>123771</th>
#       <td>운동화사공 얼마나 인기가 많던지 겨울은 올블랙 정사이즈공 키높이깔창 깔아도 티안나고...</td>
#       <td>[운동, 사공, 얼마나, 인기, 많, 겨울, 올, 블랙, 235, 정, 사이즈, 공...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

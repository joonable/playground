# %%
import pandas as pd
import re

# %%
df_text = pd.read_pickle('./data/df_temp_text.pkl')
df_term = pd.read_pickle('./data/df_temp_term.pkl')

# %%
df = df_text.merge(on=['m_id'], right=df_term)
df.term_vectors = df.term_vectors.apply(lambda term_vector: term_vector.split() if term_vector else None)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>best_flag</th>
#       <th>m_id</th>
#       <th>score</th>
#       <th>text</th>
#       <th>term_vectors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>None</td>
#       <td>134575613</td>
#       <td>80</td>
#       <td>비니스타일 이에요\n귀마게가 없어도 되는 모자고\n겨울라운딩용으로 잘샀네요</td>
#       <td>[비니, 스타일, 귀, 마게, 없, 되, 모자, 겨울, 라운, 딩, 잘, 사]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C</td>
#       <td>134575597</td>
#       <td>100</td>
#       <td>요즘 소이현씨 패딩이 인기라고 해서 구매했는데요!\n정말 너무 이뻐요! 실제로 받아...</td>
#       <td>[요즘, 소이현, 씨, 패딩, 인기, 하, 구매, 정말, 너무, 이쁘, 실제로, 받...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>134575605</td>
#       <td>100</td>
#       <td>기타등등 김종배 오늘 보험 가입해야 하나 하나 더 많은 것 같습니다 아 근데 나 진...</td>
#       <td>[기타, 등등, 김종배, 오늘, 보험, 가입, 하나, 하나, 더, 많, 것, 같, ...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>None</td>
#       <td>134575587</td>
#       <td>80</td>
#       <td>좋아요\n귀까지 내려오고\n머리보온띠가 분리돼서\n다른모자에도활용할수\n있을꺼같네요</td>
#       <td>[좋, 귀, 내려오, 머리, 보온, 띠, 분리, 다른, 모자, 활용, 수, 있, 것...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>None</td>
#       <td>134575624</td>
#       <td>100</td>
#       <td>배송너무빨라 놀랐어요 디자인제품력모두만족합니다</td>
#       <td>[배송, 너무, 빠르, 놀라, 디자인, 제품, 력, 모두, 만족]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
def cleansing_text(text):
    text = re.sub(pattern='\n|ㆍ|\r|\.|,|;|:|<|>|-|_|=|\+|/|\?|!|@|\(|\)|\*|&|！|\^|#|%|\$|~|？|\[|\]|\"|[0-9]', repl=" ", string=text)
    text = re.sub(pattern='( )+', repl=' ', string=text)
    text = re.sub(pattern='(ㅎ)+', repl='ㅎ', string=text)
    text = re.sub(pattern='(ㅋ)+', repl='ㅋ', string=text)
    text = re.sub(pattern='(ㅠ|ㅜ)+', repl='ㅠ', string=text)
    return text

df.text = df.text.apply(lambda x: cleansing_text(text=x) if x else None)
df.head()

# %%
df.sample(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>best_flag</th>
#       <th>m_id</th>
#       <th>score</th>
#       <th>text</th>
#       <th>term_vectors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>345087</th>
#       <td>None</td>
#       <td>135109759</td>
#       <td>100</td>
#       <td>상품평가</td>
#       <td>[상품, 평가]</td>
#     </tr>
#     <tr>
#       <th>179411</th>
#       <td>None</td>
#       <td>134717417</td>
#       <td>100</td>
#       <td>A 파일과 필통 넣어다니고 있는데 아주 깔끔하고 제법들어갑니다 완전 만족이요</td>
#       <td>[a, 4, 파일, 필통, 넣, 다니, 있, 아주, 깔끔, 제법, 들어가, 완전, 만족]</td>
#     </tr>
#     <tr>
#       <th>703570</th>
#       <td>None</td>
#       <td>134963006</td>
#       <td>100</td>
#       <td>진짜이쁘네요 ♡</td>
#       <td>[진짜, 이쁘]</td>
#     </tr>
#     <tr>
#       <th>381909</th>
#       <td>None</td>
#       <td>134756271</td>
#       <td>100</td>
#       <td>칫솔모가 튼튼하네요</td>
#       <td>[칫, 솔, 모, 튼튼]</td>
#     </tr>
#     <tr>
#       <th>102704</th>
#       <td>None</td>
#       <td>134926895</td>
#       <td>100</td>
#       <td>닥스 여성 모직 장갑 좋아요</td>
#       <td>[닥스, 여성, 모직, 장갑, 좋]</td>
#     </tr>
#     <tr>
#       <th>19606</th>
#       <td>None</td>
#       <td>134700038</td>
#       <td>100</td>
#       <td>맘에들어요</td>
#       <td>[맘, 듣]</td>
#     </tr>
#     <tr>
#       <th>514365</th>
#       <td>None</td>
#       <td>134895154</td>
#       <td>65</td>
#       <td>오자마자 사용해봤는대 향이 너 무 강하네요 품질력은 아직모르겠네요 암튼 좋았으면하네요</td>
#       <td>[오, 사용, 보, 향, 너, 강, 품질, 아직, 모르, 암튼, 좋, 하]</td>
#     </tr>
#     <tr>
#       <th>72535</th>
#       <td>None</td>
#       <td>134906868</td>
#       <td>100</td>
#       <td>배송빠르고 저렴하게 구매했어요 제품도 좋아요</td>
#       <td>[배송, 빠르, 저렴, 구매, 제품, 좋]</td>
#     </tr>
#     <tr>
#       <th>554629</th>
#       <td>None</td>
#       <td>135022234</td>
#       <td>100</td>
#       <td>상품평가</td>
#       <td>[상품, 평가]</td>
#     </tr>
#     <tr>
#       <th>293788</th>
#       <td>None</td>
#       <td>135594839</td>
#       <td>100</td>
#       <td>좋네요 구라구래도</td>
#       <td>[좋, 구라, 구래]</td>
#     </tr>
#     <tr>
#       <th>382784</th>
#       <td>None</td>
#       <td>134750731</td>
#       <td>100</td>
#       <td>촉촉하고 가벼운 느낌 참 좋아요</td>
#       <td>[촉촉, 가볍, 느낌, 참, 좋]</td>
#     </tr>
#     <tr>
#       <th>37672</th>
#       <td>None</td>
#       <td>134951835</td>
#       <td>80</td>
#       <td>다맘에 드는데 밥공기가 겹쳐져 잇어 빼다가 바로 깨지네여</td>
#       <td>[다, 맘, 들, 밥, 공기, 겹치, 지, 있, 빼, 바로, 깨지]</td>
#     </tr>
#     <tr>
#       <th>663131</th>
#       <td>None</td>
#       <td>134773284</td>
#       <td>100</td>
#       <td>요즘은 아이들의 제 의 교복인듯해요 이쁩니다 질도 좋구요</td>
#       <td>[요, 즘, 아이, 2, 교복, 듯, 이, 질, 좋]</td>
#     </tr>
#     <tr>
#       <th>501763</th>
#       <td>None</td>
#       <td>134774198</td>
#       <td>90</td>
#       <td>가격도괜찮고배송도빨라요</td>
#       <td>[가격, 괜찮, 배송, 빠르]</td>
#     </tr>
#     <tr>
#       <th>185160</th>
#       <td>None</td>
#       <td>134746504</td>
#       <td>85</td>
#       <td>가격대비 괞찮네요 헬스용으로 샀는데 겨울이 지나면 입어야 할것 같아요</td>
#       <td>[가격, 대비, 헬스, 사, 겨울, 지나, 입, 하, 것, 같]</td>
#     </tr>
#     <tr>
#       <th>96496</th>
#       <td>None</td>
#       <td>134851534</td>
#       <td>100</td>
#       <td>잘 받았습니다 저렴하게 구매했네요</td>
#       <td>[잘, 받, 저렴, 구매]</td>
#     </tr>
#     <tr>
#       <th>305286</th>
#       <td>None</td>
#       <td>135323672</td>
#       <td>95</td>
#       <td>머리쿵 너무 많이해서 결국 삿는데 너무 좋네요 ㅋㅌ 근데 안깔여있는 부분으로 가서 ...</td>
#       <td>[머리, 쿵, 너무, 많이, 하, 결국, 삿, 늘, 너무, 좋, ㅋ, 근데, 안, ...</td>
#     </tr>
#     <tr>
#       <th>75423</th>
#       <td>None</td>
#       <td>134919339</td>
#       <td>85</td>
#       <td>이뿌긴하나 바닥 미끄러워요 ㅠ</td>
#       <td>[이, 뿌, 하나, 바닥, 미끄럽]</td>
#     </tr>
#     <tr>
#       <th>561777</th>
#       <td>None</td>
#       <td>135075839</td>
#       <td>100</td>
#       <td>좋아요 좋아요 좋아요</td>
#       <td>[좋, 좋, 좋]</td>
#     </tr>
#     <tr>
#       <th>481534</th>
#       <td>None</td>
#       <td>134672430</td>
#       <td>100</td>
#       <td>매번 잘사용중이에요</td>
#       <td>[매번, 잘, 사용, 중]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = df.dropna(subset=['text', 'term_vectors'])

# %%
df = df.reset_index(drop=True)
df.to_pickle('./data/df_dataset.pkl')

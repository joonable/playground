# %%
import pandas as pd
import seaborn as sns
import numpy as np
from itertools import chain
import re
# %matplotlib inline

# %%
df = pd.read_pickle('df_dataset.pkl')

# %%
corpus = " ".join(df.text.tolist())

# %%
corpus = re.sub(pattern='\n|\t|ㆍ|\r|\.|,|;|:|<|>|-|_|=|\+|/|\?|!|@|\(|\)|\*|&|！|\^|#|%|\$|~|？|\[|\]|\"|[0-9]', repl=" ", string=corpus)
corpus = re.sub(pattern='( )+', repl=' ', string=corpus)
corpus = re.sub(pattern='(ㅎ)+', repl='ㅎ', string=corpus)
corpus = re.sub(pattern='(ㅋ)+', repl='ㅋ', string=corpus)

# %%
corpus[:100]
# Out:
# '또 주문 합니다 잇몸에 자극이 없어서 좋아욤 흡수력은 좋은고 같구요 다른 비타민씨제품이 요즘 약간 속당김이 느껴지는거 같아 바꿔볼까 고민중입니다 이너로 입기에도 충전재가 약하네요 '

# %%
from collections import defaultdict
count= defaultdict(lambda: 0)

# for doc in docs:
for word in corpus.split():
    n = len(word)
    for e in range(1, n+1):
        count[word[:e]] += 1

# %%
def cohesion(w):
    try:
        c = pow(count[w]/(count[w[0]]), 1/(len(w)-1))
        return c
    except ZeroDivisionError:
        print(w)
        exit()

def ltokenize(w):
    n = len(w)
    if n <= 2: 
        return (w, '') 
    
    tokens = []
    for e in range(2, n+1):
        tokens.append((w[:e], w[e:], cohesion(w[:e])))
    tokens = sorted(tokens, key=lambda x:-x[2])
    return tokens[0][:2]

# %%
df = pd.DataFrame.from_dict(count, orient='index')
df = df.reset_index()
df.columns = ['word', 'cnt']
df.word = df.word.astype('str')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>word</th>
#       <th>cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>또</td>
#       <td>2939</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>주</td>
#       <td>15517</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>주문</td>
#       <td>9938</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>합</td>
#       <td>3219</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>합니</td>
#       <td>3069</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# c = pow(count[w]/(count[w[0]]), 1/(len(w)-1))

def cohesion(row):
     if len(row['word']) != 1:
        return 1
        return pow(row['cnt']/(df.loc[df.word == row['word'][0], 'cnt']), 1/(len(row['word'])-1))
     else:
        return None

df['cohesion'] = df.apply(lambda row: cohesion(row), axis=1) 
# {k: cohesion(k) for k in count.keys() if len(k) != 1}

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>word</th>
#       <th>cnt</th>
#       <th>cohesion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>또</td>
#       <td>2939</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>주</td>
#       <td>15517</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>주문</td>
#       <td>9938</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>합</td>
#       <td>3219</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>합니</td>
#       <td>3069</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
ltokenize_score = {k: ltokenize(k) for k in cohesion_score.keys()}

# %%
df = pd.DataFrame.from_dict(cohesion_score, orient='index')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>주문</th>
#       <td>0.640459</td>
#     </tr>
#     <tr>
#       <th>합니</th>
#       <td>0.953402</td>
#     </tr>
#     <tr>
#       <th>합니다</th>
#       <td>0.968757</td>
#     </tr>
#     <tr>
#       <th>잇몸</th>
#       <td>0.209945</td>
#     </tr>
#     <tr>
#       <th>잇몸에</th>
#       <td>0.246523</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cohesion_score
# Out:
# {'또': ('또', ''),
#  '주': ('주', ''),
#  '주문': ('주문', ''),
#  '합': ('합', ''),
#  '합니': ('합니', ''),
#  '합니다': ('합니', '다'),
#  '잇': ('잇', ''),
#  '잇몸': ('잇몸', ''),
#  '잇몸에': ('잇몸', '에'),
#  '자': ('자', ''),
#  '자극': ('자극', ''),
#  '자극이': ('자극', '이'),
#  '없': ('없', ''),
#  '없어': ('없어', ''),
#  '없어서': ('없어', '서'),
#  '좋': ('좋', ''),
#  '좋아': ('좋아', ''),
#  '좋아욤': ('좋아', '욤'),
#  '흡': ('흡', ''),
#  '흡수': ('흡수', ''),
#  '흡수력': ('흡수', '력'),
#  '흡수력은': ('흡수', '력은'),
#  '좋은': ('좋은', ''),
#  '좋은고': ('좋은', '고'),
#  '같': ('같', ''),
#  '같구': ('같구', ''),
#  '같구요': ('같구', '요'),
#  '다': ('다', ''),
#  '다른': ('다른', ''),
#  '비': ('비', ''),
#  '비타': ('비타', ''),
#  '비타민': ('비타', '민'),
#  '비타민씨': ('비타', '민씨'),
#  '비타민씨제': ('비타', '민씨제'),
#  '비타민씨제품': ('비타', '민씨제품'),
#  '비타민씨제품이': ('비타', '민씨제품이'),
#  '요': ('요', ''),
#  '요즘': ('요즘', ''),
#  '약': ('약', ''),
#  '약간': ('약간', ''),
#  '속': ('속', ''),
#  '속당': ('속당', ''),
#  '속당김': ('속당김', ''),
#  '속당김이': ('속당김', '이'),
#  '느': ('느', ''),
#  '느껴': ('느껴', ''),
#  '느껴지': ('느껴', '지'),
#  '느껴지는': ('느껴', '지는'),
#  '느껴지는거': ('느껴', '지는거'),
#  '같아': ('같아', ''),
#  '바': ('바', ''),
#  '바꿔': ('바꿔', ''),
#  '바꿔볼': ('바꿔', '볼'),
#  '바꿔볼까': ('바꿔', '볼까'),
#  '고': ('고', ''),
#  '고민': ('고민', ''),
#  '고민중': ('고민', '중'),
#  '고민중입': ('고민', '중입'),
#  '고민중입니': ('고민', '중입니'),
#  '고민중입니다': ('고민', '중입니다'),
#  '이': ('이', ''),
#  '이너': ('이너', ''),
#  '이너로': ('이너', '로'),
#  '입': ('입', ''),
#  '입기': ('입기', ''),
#  '입기에': ('입기', '에'),
#  '입기에도': ('입기', '에도'),
#  '충': ('충', ''),
#  '충전': ('충전', ''),
#  '충전재': ('충전', '재'),
#  '충전재가': ('충전', '재가'),
#  '약하': ('약하', ''),
#  '약하네': ('약하', '네'),
#  '약하네요': ('약하', '네요'),
#  '조': ('조', ''),
#  '조끼': ('조끼', ''),
#  '빼': ('빼', ''),
#  '빼고': ('빼고', ''),
#  '겉': ('겉', ''),
#  '겉옷': ('겉옷', ''),
#  '위': ('위', ''),
#  '위에': ('위에', ''),
#  '털': ('털', ''),
#  '털조': ('털조', ''),
#  '털조끼': ('털조끼', ''),
#  '입고': ('입고', ''),
#  '외': ('외', ''),
#  '외출': ('외출', ''),
#  '했': ('했', ''),
#  '했는': ('했는', ''),
#  '했는데': ('했는', '데'),
#  '바람': ('바람', ''),
#  '숭': ('숭', ''),
#  '숭숭': ('숭숭', ''),
#  '들': ('들', ''),
#  '들어': ('들어', ''),
#  '오': ('오', ''),
#  '오네': ('오네', ''),
#  '오네요': ('오네', '요'),
#  '추': ('추', ''),
#  '추워': ('추워', ''),
#  '추워요': ('추워', '요'),
#  '보': ('보', ''),
#  '보온': ('보온', ''),
#  '보온성': ('보온', '성'),
#  '아': ('아', ''),
#  '아쉬': ('아쉬', ''),
#  '아쉬워': ('아쉬', '워'),
#  '아쉬워요': ('아쉬', '워요'),
#  '딸': ('딸', ''),
#  '딸아': ('딸아', ''),
#  '딸아이': ('딸아', '이'),
#  '코': ('코', ''),
#  '코에': ('코에', ''),
#  '해': ('해', ''),
#  '해봤': ('해봤', ''),
#  '해봤는': ('해봤', '는'),
#  '해봤는데': ('해봤', '는데'),
#  '잘': ('잘', ''),
#  '안': ('안', ''),
#  '안빠': ('안빠', ''),
#  '안빠지': ('안빠', '지'),
#  '안빠지네': ('안빠', '지네'),
#  '안빠지네요': ('안빠', '지네요'),
#  'ㅠ': ('ㅠ', ''),
#  'ㅠㅠ': ('ㅠㅠ', ''),
#  '목': ('목', ''),
#  '목욕': ('목욕', ''),
#  '목욕후': ('목욕', '후'),
#  '모': ('모', ''),
#  '모공': ('모공', ''),
#  '모공이': ('모공', '이'),
#  '열': ('열', ''),
#  '열렸': ('열렸', ''),
#  '열렸을': ('열렸', '을'),
#  '열렸을때': ('열렸', '을때'),
#  '다시': ('다시', ''),
#  '해보': ('해보', ''),
#  '해보려': ('해보', '려'),
#  '해보려구': ('해보', '려구'),
#  '해보려구요': ('해보', '려구요'),
#  '빠': ('빠', ''),
#  '빠른': ('빠른', ''),
#  '배': ('배', ''),
#  '배송': ('배송', ''),
#  '감': ('감', ''),
#  '감사': ('감사', ''),
#  '감사합': ('감사', '합'),
#  '감사합니': ('감사', '합니'),
#  '감사합니다': ('감사', '합니다'),
#  '아이': ('아이', ''),
#  '아이가': ('아이', '가'),
#  '너': ('너', ''),
#  '너무': ('너무', ''),
#  '마': ('마', ''),
#  '마음': ('마음', ''),
#  '마음에': ('마음', '에'),
#  '정': ('정', ''),
#  '정말': ('정말', ''),
#  '내': ('내', ''),
#  '돈': ('돈', ''),
#  '돈주': ('돈주', ''),
#  '돈주고': ('돈주', '고'),
#  '구': ('구', ''),
#  '구입': ('구입', ''),
#  '구입해': ('구입', '해'),
#  '구입해서': ('구입', '해서'),
#  '성': ('성', ''),
#  '성질': ('성질', ''),
#  '성질버': ('성질', '버'),
#  '성질버린': ('성질', '버린'),
#  '성질버린다': ('성질', '버린다'),
#  '성질버린다라': ('성질', '버린다라'),
#  '성질버린다라는': ('성질', '버린다라는'),
#  '표': ('표', ''),
#  '표현': ('표현', ''),
#  '표현생': ('표현', '생'),
#  '표현생각': ('표현', '생각'),
#  '표현생각나': ('표현', '생각나'),
#  '표현생각나는': ('표현', '생각나는'),
#  '제': ('제', ''),
#  '제품': ('제품', ''),
#  '털고': ('털고', ''),
#  '찍': ('찍', ''),
#  '찍찍': ('찍찍', ''),
#  '찍찍이': ('찍찍', '이'),
#  '찍찍이로': ('찍찍', '이로'),
#  '굴': ('굴', ''),
#  '굴리': ('굴리', ''),
#  '굴리고': ('굴리고', ''),
#  '청': ('청', ''),
#  '청소': ('청소', ''),
#  '청소기': ('청소', '기'),
#  '청소기로': ('청소', '기로'),
#  '빨': ('빨', ''),
#  '빨아': ('빨아', ''),
#  '빨아내': ('빨아', '내'),
#  '빨아내고': ('빨아', '내고'),
#  '찍고': ('찍고', ''),
#  '찍고를': ('찍고', '를'),
#  '어': ('어', ''),
#  '어제': ('어제', ''),
#  '첫': ('첫', ''),
#  '첫눈': ('첫눈', ''),
#  '첫눈와': ('첫눈', '와'),
#  '첫눈와서': ('첫눈', '와서'),
#  '잠': ('잠', ''),
#  '잠깐': ('잠깐', ''),
#  '두': ('두', ''),
#  '두르': ('두르', ''),
#  '두르고': ('두르', '고'),
#  '나': ('나', ''),
#  '나갔': ('나갔', ''),
#  '나갔다': ('나갔', '다'),
#  '나갔다가': ('나갔', '다가'),
#  '헉': ('헉', ''),
#  '이런': ('이런', ''),
#  '이런제': ('이런', '제'),
#  '이런제품': ('이런', '제품'),
#  '팔': ('팔', ''),
#  '팔지': ('팔지', ''),
#  '맙': ('맙', ''),
#  '맙시': ('맙시', ''),
#  '맙시다': ('맙시다', ''),
#  '맙시다\U0001f928': ('맙시다', '\U0001f928'),
#  '좋아요': ('좋아', '요'),
#  '좋아요게': ('좋아', '요게'),
#  '좋아요게소': ('좋아', '요게소'),
#  '좋아요게소그': ('좋아', '요게소그'),
#  '좋아요게소그는': ('좋아', '요게소그는'),
#  '좋아요게소그는데': ('좋아', '요게소그는데'),
#  '좋아요게소그는데에': ('좋아', '요게소그는데에'),
#  '좋아요게소그는데에센': ('좋아', '요게소그는데에센'),
#  '좋아요게소그는데에센스': ('좋아', '요게소그는데에센스'),
#  '좋아요게소그는데에센스는': ('좋아', '요게소그는데에센스는'),
#  '좋아요게소그는데에센스는윤': ('좋아', '요게소그는데에센스는윤'),
#  '좋아요게소그는데에센스는윤조': ('좋아', '요게소그는데에센스는윤조'),
#  '좋아요게소그는데에센스는윤조가': ('좋아', '요게소그는데에센스는윤조가'),
#  '좋아요게소그는데에센스는윤조가제': ('좋아', '요게소그는데에센스는윤조가제'),
#  '좋아요게소그는데에센스는윤조가제일': ('좋아', '요게소그는데에센스는윤조가제일'),
#  '좋아요게소그는데에센스는윤조가제일인': ('좋아', '요게소그는데에센스는윤조가제일인'),
#  '좋아요게소그는데에센스는윤조가제일인듯': ('좋아', '요게소그는데에센스는윤조가제일인듯'),
#  '쫀': ('쫀', ''),
#  '쫀쫀': ('쫀쫀', ''),
#  '쫀쫀한': ('쫀쫀', '한'),
#  '쫀쫀한건': ('쫀쫀', '한건'),
#  '좋은데': ('좋은', '데'),
#  '입고벗': ('입고', '벗'),
#  '입고벗기': ('입고', '벗기'),
#  '입고벗기가': ('입고', '벗기가'),
#  '기': ('기', ''),
#  '기술': ('기술', ''),
#  '기술이': ('기술', '이'),
#  '필': ('필', ''),
#  '필요': ('필요', ''),
#  '필요할': ('필요', '할'),
#  '필요할듯': ('필요', '할듯'),
#  '싸': ('싸', ''),
#  '싸이': ('싸이', ''),
#  '싸이즈': ('싸이', '즈'),
#  '교': ('교', ''),
#  '교환': ('교환', ''),
#  '교환으': ('교환', '으'),
#  '교환으로': ('교환', '으로'),
#  '교환비': ('교환', '비'),
#  '교환비까': ('교환', '비까'),
#  '교환비까지': ('교환', '비까지'),
#  'ㅜ': ('ㅜ', ''),
#  'ㅜㅜ': ('ㅜㅜ', ''),
#  '역': ('역', ''),
#  '역시': ('역시', ''),
#  '로': ('로', ''),
#  '로보': ('로보', ''),
#  '로보네': ('로보', '네'),
#  '로보네요': ('로보', '네요'),
#  '타': ('타', ''),
#  '타방': ('타방', ''),
#  '타방송': ('타방송', ''),
#  '무': ('무', ''),
#  '무스': ('무스', ''),
#  '무스탕': ('무스', '탕'),
#  '입어': ('입어', ''),
#  '입어보': ('입어', '보'),
#  '입어보고': ('입어', '보고'),
#  '반': ('반', ''),
#  '반품': ('반품', ''),
#  '반품만': ('반품', '만'),
#  '두번': ('두번', ''),
#  '로보를': ('로보', '를'),
#  '이거': ('이거', ''),
#  '이거다': ('이거', '다'),
#  '싶': ('싶', ''),
#  '싶어': ('싶어', ''),
#  '기쁜': ('기쁜', ''),
#  '마음으': ('마음', '으'),
#  '마음으로': ('마음', '으로'),
#  '입습': ('입습', ''),
#  '입습니': ('입습니', ''),
#  '입습니다': ('입습니', '다'),
#  '가': ('가', ''),
#  '가볍': ('가볍', ''),
#  '가볍습': ('가볍', '습'),
#  '가볍습니': ('가볍', '습니'),
#  '가볍습니다': ('가볍', '습니다'),
#  '발': ('발', ''),
#  '발볼': ('발볼', ''),
#  '발볼이': ('발볼', '이'),
#  '넓': ('넓', ''),
#  '넓은': ('넓은', ''),
#  '사': ('사', ''),
#  '사람': ('사람', ''),
#  '사람은': ('사람', '은'),
#  '불': ('불', ''),
#  '불편': ('불편', ''),
#  '불편할': ('불편', '할'),
#  '불편할듯': ('불편', '할듯'),
#  '배송도': ('배송', '도'),
#  '빨르': ('빨르', ''),
#  '빨르고': ('빨르', '고'),
#  '사이': ('사이', ''),
#  '사이즈': ('사이', '즈'),
#  '사이즈도': ('사이', '즈도'),
#  '잘맞': ('잘맞', ''),
#  '잘맞아': ('잘맞', '아'),
#  '잘맞아서': ('잘맞', '아서'),
#  '신': ('신', ''),
#  '신랑': ('신랑', ''),
#  '신랑이': ('신랑', '이'),
#  '좋아라': ('좋아', '라'),
#  '좋아라하': ('좋아', '라하'),
#  '좋아라하네': ('좋아', '라하네'),
#  '좋아라하네요': ('좋아', '라하네요'),
#  '완': ('완', ''),
#  '완전': ('완전', ''),
#  '완전강': ('완전', '강'),
#  '완전강력': ('완전', '강력'),
#  '완전강력추': ('완전', '강력추'),
#  '완전강력추천': ('완전', '강력추천'),
#  '완전강력추천합': ('완전', '강력추천합'),
#  '완전강력추천합니': ('완전', '강력추천합니'),
#  '완전강력추천합니다': ('완전', '강력추천합니다'),
#  '센': ('센', ''),
#  '센티': ('센티', ''),
#  '키': ('키', ''),
#  '키로': ('키로', ''),
#  '사이즈시': ('사이', '즈시'),
#  '사이즈시켰': ('사이', '즈시켰'),
#  '사이즈시켰는': ('사이', '즈시켰는'),
#  '사이즈시켰는데': ('사이', '즈시켰는데'),
#  '넉': ('넉', ''),
#  '넉넉': ('넉넉', ''),
#  '넉넉하': ('넉넉', '하'),
#  '넉넉하게': ('넉넉', '하게'),
#  '맞': ('맞', ''),
#  '맞아': ('맞아', ''),
#  '맞아서': ('맞아', '서'),
#  '내년': ('내년', ''),
#  '내년까': ('내년', '까'),
#  '내년까지': ('내년', '까지'),
#  '입힐': ('입힐', ''),
#  '입힐수': ('입힐', '수'),
#  '입힐수있': ('입힐', '수있'),
#  '입힐수있을': ('입힐', '수있을'),
#  '입힐수있을꺼': ('입힐', '수있을꺼'),
#  '입힐수있을꺼같': ('입힐', '수있을꺼같'),
#  '입힐수있을꺼같아': ('입힐', '수있을꺼같아'),
#  '입힐수있을꺼같아요': ('입힐', '수있을꺼같아요'),
#  '후': ('후', ''),
#  '후드': ('후드', ''),
#  '후드에': ('후드', '에'),
#  '퍼': ('퍼', ''),
#  '퍼도': ('퍼도', ''),
#  '풍': ('풍', ''),
#  '풍성': ('풍성', ''),
#  '풍성하': ('풍성', '하'),
#  '풍성하고': ('풍성', '하고'),
#  '마감': ('마감', ''),
#  '마감도': ('마감', '도'),
#  '훌': ('훌', ''),
#  '훌륭': ('훌륭', ''),
#  '훌륭하': ('훌륭', '하'),
#  '훌륭하네': ('훌륭', '하네'),
#  '훌륭하네요': ('훌륭', '하네요'),
#  '올': ('올', ''),
#  '올겨': ('올겨', ''),
#  '올겨울': ('올겨', '울'),
#  '입힐께': ('입힐', '께'),
#  '입힐께요': ('입힐', '께요'),
#  '나는': ('나는', ''),
#  '큰': ('큰', ''),
#  '큰사': ('큰사', ''),
#  '큰사이': ('큰사', '이'),
#  '큰사이즈': ('큰사', '이즈'),
#  '큰사이즈사': ('큰사', '이즈사'),
#  '큰사이즈사용': ('큰사', '이즈사용'),
#  '큰사이즈사용하': ('큰사', '이즈사용하'),
#  '큰사이즈사용하는': ('큰사', '이즈사용하는'),
#  '큰사이즈사용하는데': ('큰사', '이즈사용하는데'),
#  '보드': ('보드', ''),
#  '보드랍': ('보드', '랍'),
#  '보드랍고': ('보드', '랍고'),
#  '따': ('따', ''),
#  '따뜻': ('따뜻', ''),
#  '따뜻해': ('따뜻', '해'),
#  '따뜻해서': ('따뜻', '해서'),
#  '좋더': ('좋더', ''),
#  '좋더라': ('좋더', '라'),
#  '좋더라구': ('좋더', '라구'),
#  '좋더라구요': ('좋더', '라구요'),
#  '이번': ('이번', ''),
#  '이번에': ('이번', '에'),
#  '자취': ('자취', ''),
#  '자취하': ('자취', '하'),
#  '자취하는': ('자취', '하는'),
#  '침': ('침', ''),
#  '침대': ('침대', ''),
#  '침대위': ('침대', '위'),
#  '침대위에': ('침대', '위에'),
#  '깔': ('깔', ''),
#  '깔아': ('깔아', ''),
#  '깔아주': ('깔아', '주'),
#  '깔아주려': ('깔아', '주려'),
#  '깔아주려고': ('깔아', '주려고'),
#  '싱': ('싱', ''),
#  '싱글': ('싱글', ''),
#  '싱글로': ('싱글', '로'),
#  '주문했': ('주문', '했'),
#  '주문했어': ('주문', '했어'),
#  '주문했어요': ('주문', '했어요'),
#  '길': ('길', ''),
#  '길이': ('길이', ''),
#  '길이길': ('길이', '길'),
#  '길이길고': ('길이', '길고'),
#  '두툼': ('두툼', ''),
#  '두툼하': ('두툼', '하'),
#  '두툼하고': ('두툼', '하고'),
#  '좋은것': ('좋은', '것'),
#  '좋은것같': ('좋은', '것같'),
#  '좋은것같아': ('좋은', '것같아'),
#  '좋은것같아요': ('좋은', '것같아요'),
#  '쿠': ('쿠', ''),
#  '쿠폰': ('쿠폰', ''),
#  '적': ('적', ''),
#  '적용': ('적용', ''),
#  '적용받': ('적용', '받'),
#  '적용받아': ('적용', '받아'),
#  '적용받아서': ('적용', '받아서'),
#  '조금': ('조금', ''),
#  '더': ('더', ''),
#  '저': ('저', ''),
#  '저렴': ('저렴', ''),
#  '저렴하': ('저렴', '하'),
#  '저렴하게': ('저렴', '하게'),
#  '구입했': ('구입', '했'),
#  '구입했어': ('구입', '했어'),
#  '구입했어요': ('구입', '했어요'),
#  '이전': ('이전', ''),
#  '이전에': ('이전', '에'),
#  '까': ('까', ''),
#  '까만': ('까만', ''),
#  '까만색': ('까만', '색'),
#  '까만색케': ('까만', '색케'),
#  '까만색케이': ('까만', '색케이'),
#  '까만색케이스': ('까만', '색케이스'),
#  '썼': ('썼', ''),
#  '썼는': ('썼는', ''),
#  '썼는데': ('썼는', '데'),
#  '아주': ('아주', ''),
#  '만': ('만', ''),
#  '만족': ('만족', ''),
#  '만족스': ('만족', '스'),
#  '만족스러': ('만족', '스러'),
#  '만족스러웠': ('만족', '스러웠'),
#  '만족스러웠어': ('만족', '스러웠어'),
#  '만족스러웠어요': ('만족', '스러웠어요'),
#  '것': ('것', ''),
#  '것도': ('것도', ''),
#  '기대': ('기대', ''),
#  '기대됩': ('기대', '됩'),
#  '기대됩니': ('기대', '됩니'),
#  '기대됩니다': ('기대', '됩니다'),
#  '틴': ('틴', ''),
#  '틴트': ('틴트', ''),
#  '틴트도': ('틴트', '도'),
#  '원': ('원', ''),
#  '원하': ('원하', ''),
#  '원하는': ('원하', '는'),
#  '색': ('색', ''),
#  '색이': ('색이', ''),
#  '왔': ('왔', ''),
#  '왔네': ('왔네', ''),
#  '왔네요': ('왔네', '요'),
#  '감사해': ('감사', '해'),
#  '감사해요': ('감사', '해요'),
#  '착': ('착', ''),
#  '착용': ('착용', ''),
#  '착용감': ('착용', '감'),
#  '착용감도': ('착용', '감도'),
#  '좋고': ('좋고', ''),
#  '넘': ('넘', ''),
#  '키가': ('키가', ''),
#  '작': ('작', ''),
#  '작은': ('작은', ''),
#  '작은데': ('작은', '데'),
#  '훨': ('훨', ''),
#  '훨씬': ('훨씬', ''),
#  '날': ('날', ''),
#  '날씬': ('날씬', ''),
#  '날씬히': ('날씬', '히'),
#  '보여': ('보여', ''),
#  '보여요': ('보여', '요'),
#  '옷': ('옷', ''),
#  '옷이': ('옷이', ''),
#  '옷이딱': ('옷이', '딱'),
#  '옷이딱맞': ('옷이', '딱맞'),
#  '옷이딱맞네': ('옷이', '딱맞네'),
#  '옷이딱맞네여': ('옷이', '딱맞네여'),
#  '조금만': ('조금', '만'),
#  '조금만더': ('조금', '만더'),
#  '조금만더커': ('조금', '만더커'),
#  '조금만더커도': ('조금', '만더커도'),
#  '조금만더커도좋': ('조금', '만더커도좋'),
#  '조금만더커도좋을': ('조금', '만더커도좋을'),
#  '조금만더커도좋을텐': ('조금', '만더커도좋을텐'),
#  '조금만더커도좋을텐데': ('조금', '만더커도좋을텐데'),
#  '따뜻하': ('따뜻', '하'),
#  '따뜻하고': ('따뜻', '하고'),
#  '슬': ('슬', ''),
#  '슬림': ('슬림', ''),
#  '슬림핏': ('슬림', '핏'),
#  '슬림핏이': ('슬림', '핏이'),
#  '슬림핏이라': ('슬림', '핏이라'),
#  '젊': ('젊', ''),
#  '젊은': ('젊은', ''),
#  '느낌': ('느낌', ''),
#  '느낌이': ('느낌', '이'),
#  '느낌이고': ('느낌', '이고'),
#  '색도': ('색도', ''),
#  '차': ('차', ''),
#  '차분': ('차분', ''),
#  '차분하': ('차분', '하'),
#  '차분하니': ('차분', '하니'),
#  '좋으': ('좋으', ''),
#  '좋으네': ('좋으', '네'),
#  '좋으네요': ('좋으', '네요'),
#  '추워진': ('추워', '진'),
#  '날씨': ('날씨', ''),
#  '날씨에': ('날씨', '에'),
#  '걱': ('걱', ''),
#  '걱정': ('걱정', ''),
#  '걱정했': ('걱정', '했'),
#  '걱정했는': ('걱정', '했는'),
#  '걱정했는데': ('걱정', '했는데'),
#  '저렴한': ('저렴', '한'),
#  '가격': ('가격', ''),
#  '가격에': ('가격', '에'),
#  '득': ('득', ''),
#  '득템': ('득템', ''),
#  '득템한': ('득템', '한'),
#  '기분': ('기분', ''),
#  '기분입': ('기분', '입'),
#  '기분입니': ('기분', '입니'),
#  '기분입니다': ('기분', '입니다'),
#  '너무두': ('너무', '두'),
#  '너무두꺼': ('너무', '두꺼'),
#  '너무두꺼운': ('너무', '두꺼운'),
#  '너무두꺼운게': ('너무', '두꺼운게'),
#  '너무두꺼운게싫': ('너무', '두꺼운게싫'),
#  '너무두꺼운게싫어': ('너무', '두꺼운게싫어'),
#  '너무두꺼운게싫어서': ('너무', '두꺼운게싫어서'),
#  '얇': ('얇', ''),
#  '얇아': ('얇아', ''),
#  '얇아서': ('얇아', '서'),
#  '얇아서좋': ('얇아', '서좋'),
#  '얇아서좋아': ('얇아', '서좋아'),
#  '얇아서좋아요': ('얇아', '서좋아요'),
#  '색상': ('색상', ''),
#  '색상이': ('색상', '이'),
#  '색상이너': ('색상', '이너'),
#  '색상이너무': ('색상', '이너무'),
#  '색상이너무마': ('색상', '이너무마'),
#  '색상이너무마음': ('색상', '이너무마음'),
#  '색상이너무마음에': ('색상', '이너무마음에'),
#  '색상이너무마음에들': ('색상', '이너무마음에들'),
#  '색상이너무마음에들어': ('색상', '이너무마음에들어'),
#  '색상이너무마음에들어요': ('색상', '이너무마음에들어요'),
#  '사지': ('사지', ''),
#  '마세': ('마세', ''),
#  '마세요': ('마세', '요'),
#  '전': ('전', ''),
#  '홈': ('홈', ''),
#  '홈쇼': ('홈쇼', ''),
#  '홈쇼핑': ('홈쇼', '핑'),
#  '매': ('매', ''),
#  '매니': ('매니', ''),
#  '매니아': ('매니', '아'),
#  '이지': ('이지', ''),
#  '이지만': ('이지', '만'),
#  '상': ('상', ''),
#  '상품': ('상품', ''),
#  '상품평': ('상품', '평'),
#  '상품평은': ('상품', '평은'),
#  '첨': ('첨', ''),
#  '씁': ('씁', ''),
#  '씁니': ('씁니', ''),
#  '씁니다': ('씁니', '다'),
#  '이렇': ('이렇', ''),
#  '이렇게': ('이렇', '게'),
#  '털빠': ('털빠', ''),
#  '털빠짐': ('털빠', '짐'),
#  '털빠짐이': ('털빠', '짐이'),
#  '심': ('심', ''),
#  '심한': ('심한', ''),
#  '옷을': ('옷을', ''),
#  '판': ('판', ''),
#  '판매': ('판매', ''),
#  '판매할': ('판매', '할'),
#  '수': ('수', ''),
#  '있': ('있', ''),
#  '있는': ('있는', ''),
#  '있는지': ('있는', '지'),
#  '이해': ('이해', ''),
#  '이해가': ('이해', '가'),
#  '갑': ('갑', ''),
#  '갑니': ('갑니', ''),
#  '갑니다': ('갑니', '다'),
#  '속옷': ('속옷', ''),
#  '속옷에': ('속옷', '에'),
#  '바지': ('바지', ''),
#  '바지에': ('바지', '에'),
#  '점': ('점', ''),
#  '점퍼': ('점퍼', ''),
#  '점퍼에': ('점퍼', '에'),
#  '심지': ('심지', ''),
#  '심지어': ('심지', '어'),
#  '침대까': ('침대', '까'),
#  '침대까지': ('침대', '까지'),
#  '온': ('온', ''),
#  '집': ('집', ''),
#  '집안': ('집안', ''),
#  '집안에': ('집안', '에'),
#  '털이': ('털이', ''),
#  '날아': ('날아', ''),
#  '날아다': ('날아', '다'),
#  '날아다니': ('날아', '다니'),
#  '날아다니고': ('날아', '다니고'),
#  '목은': ('목은', ''),
#  '까끄': ('까끄', ''),
#  '까끄럽': ('까끄', '럽'),
#  '까끄럽고': ('까끄', '럽고'),
#  '장': ('장', ''),
#  '장난': ('장난', ''),
#  '아닙': ('아닙', ''),
#  '아닙니': ('아닙니', ''),
#  '아닙니다': ('아닙니', '다'),
#  '갖': ('갖', ''),
#  '갖다': ('갖다', ''),
#  '버': ('버', ''),
#  '버리': ('버리', ''),
#  '버리고': ('버리', '고'),
#  '싶은': ('싶은', ''),
#  '심정': ('심정', ''),
#  '심정입': ('심정', '입'),
#  '심정입니': ('심정', '입니'),
#  '심정입니다': ('심정', '입니다'),
#  '이쁘': ('이쁘', ''),
#  '이쁘네': ('이쁘', '네'),
#  '이쁘네요': ('이쁘', '네요'),
#  '아들': ('아들', ''),
#  '아들이': ('아들', '이'),
#  '엄': ('엄', ''),
#  '엄청': ('엄청', ''),
#  '좋아해': ('좋아', '해'),
#  '좋아해요': ('좋아', '해요'),
#  '에': ('에', ''),
#  '대': ('대', ''),
#  '대한': ('대한', ''),
#  '후기': ('후기', ''),
#  '후기를': ('후기', '를'),
#  '남': ('남', ''),
#  '남겨': ('남겨', ''),
#  '남겨주': ('남겨', '주'),
#  '남겨주세': ('남겨', '주세'),
#  '남겨주세요': ('남겨', '주세요'),
#  '작성': ('작성', ''),
#  '작성시': ('작성', '시'),
#  '주의': ('주의', ''),
#  '주의사': ('주의', '사'),
#  '주의사항': ('주의', '사항'),
#  '작성된': ('작성', '된'),
#  '사진': ('사진', ''),
#  '동': ('동', ''),
#  '동영': ('동영', ''),
#  '동영상': ('동영상', ''),
#  '포': ('포', ''),
#  '포함': ('포함', ''),
#  '은': ('은', ''),
#  'G': ('G', ''),
#  'GS': ('GS', ''),
#  'S': ('S', ''),
#  'SH': ('SH', ''),
#  'SHO': ('SH', 'O'),
#  'SHOP': ('SH', 'OP'),
#  '및': ('및', ''),
#  '제휴': ('제휴', ''),
#  '제휴사': ('제휴', '사'),
#  '마케': ('마케', ''),
#  '마케팅': ('마케', '팅'),
#  '마케팅에': ('마케', '팅에'),
#  '활': ('활', ''),
#  '활용': ('활용', ''),
#  '활용될': ('활용', '될'),
#  '있으': ('있으', ''),
#  '있으며': ('있으', '며'),
#  '다음': ('다음', ''),
#  '내용': ('내용', ''),
#  '내용의': ('내용', '의'),
#  '글': ('글', ''),
#  '글은': ('글은', ''),
#  '관': ('관', ''),
#  '관리': ('관리', ''),
#  '관리자': ('관리', '자'),
#  '관리자에': ('관리', '자에'),
#  '의': ('의', ''),
#  '의해': ('의해', ''),
#  '임': ('임', ''),
#  '임의': ('임의', ''),
#  '삭': ('삭', ''),
#  '삭제': ('삭제', ''),
#  '삭제될': ('삭제', '될'),
#  '있습': ('있습', ''),
#  '있습니': ('있습', '니'),
#  '있습니다': ('있습', '니다'),
#  '전화': ('전화', ''),
#  '전화번': ('전화', '번'),
#  '전화번호': ('전화', '번호'),
#  '주민': ('주민', ''),
#  '주민번': ('주민번', ''),
#  '주민번호': ('주민번호', ''),
#  '이름': ('이름', ''),
#  '아이디': ('아이', '디'),
#  '등': ('등', ''),
#  '개': ('개', ''),
#  '개인': ('개인', ''),
#  '개인정': ('개인', '정'),
#  '개인정보': ('개인', '정보'),
#  '개인정보가': ('개인', '정보가'),
#  '포함된': ('포함', '된'),
#  '저작': ('저작', ''),
#  '저작권': ('저작', '권'),
#  '저작권침': ('저작', '권침'),
#  '저작권침해': ('저작', '권침해'),
#  '음': ('음', ''),
#  '음란': ('음란', ''),
#  '욕': ('욕', ''),
#  '욕설': ('욕설', ''),
#  '비방': ('비방', ''),
#  '비방글': ('비방글', ''),
#  '광': ('광', ''),
#  '광고': ('광고', ''),
#  '홍': ('홍', ''),
#  '홍보': ('홍보', ''),
#  '홍보성': ('홍보', '성'),
#  '글을': ('글을', ''),
#  '등록': ('등록', ''),
#  '등록한': ('등록', '한'),
#  '경': ('경', ''),
#  '경우': ('경우', ''),
#  '마데': ('마데', ''),
#  '마데카': ('마데', '카'),
#  '마데카크': ('마데', '카크'),
#  '마데카크림': ('마데', '카크림'),
#  '좋아서': ('좋아', '서'),
#  '계': ('계', ''),
#  '계속': ('계속', ''),
#  '사용': ('사용', ''),
#  '사용하': ('사용', '하'),
#  '사용하고': ('사용', '하고'),
#  '사용하고있': ('사용', '하고있'),
#  '사용하고있는': ('사용', '하고있는'),
#  '사용하고있는데': ('사용', '하고있는데'),
#  '시': ('시', ''),
#  '시즌': ('시즌', ''),
#  '는': ('는', ''),
#  '묽': ('묽', ''),
#  '묽고': ('묽고', ''),
#  '얼': ('얼', ''),
#  '얼굴': ('얼굴', ''),
#  '얼굴이': ('얼굴', '이'),
#  '많': ('많', ''),
#  '많이': ('많이', ''),
#  '건': ('건', ''),
#  '건조': ('건조', ''),
#  '건조해': ('건조', '해'),
#  '건조해요': ('건조', '해요'),
#  '를': ('를', ''),
#  '구매': ('구매', ''),
#  '구매할': ('구매', '할'),
#  '구매할수': ('구매', '할수'),
#  '구매할수없': ('구매', '할수없'),
#  '구매할수없나': ('구매', '할수없나'),
#  '구매할수없나요': ('구매', '할수없나요'),
#  '세': ('세', ''),
#  '세트': ('세트', ''),
#  '세트로': ('세트', '로'),
#  '아웃': ('아웃', ''),
#  '아웃도': ('아웃', '도'),
#  '아웃도어': ('아웃', '도어'),
#  '안쪽': ('안쪽', ''),
#  '카': ('카', ''),
#  '카라': ('카라', ''),
#  '카라부': ('카라', '부'),
#  '카라부분': ('카라', '부분'),
#  '카라부분이': ('카라', '부분이'),
#  '화': ('화', ''),
#  '화장': ('화장', ''),
#  '화장품': ('화장', '품'),
#  '화장품이': ('화장', '품이'),
#  '자꾸': ('자꾸', ''),
#  '묻': ('묻', ''),
#  '묻어': ('묻어', ''),
#  '묻어서': ('묻어', '서'),
#  '닦': ('닦', ''),
#  '닦을': ('닦을', ''),
#  '닦을려': ('닦을', '려'),
#  '닦을려고': ('닦을', '려고'),
#  '닦을려고삿': ('닦을', '려고삿'),
#  '닦을려고삿어': ('닦을', '려고삿어'),
#  '닦을려고삿어요': ('닦을', '려고삿어요'),
#  '모자': ('모자', ''),
#  '이마': ('이마', ''),
#  '이마부': ('이마', '부'),
#  '이마부분': ('이마', '부분'),
#  '이마부분하': ('이마', '부분하'),
#  '이마부분하고': ('이마', '부분하고'),
#  '이마부분하고요': ('이마', '부분하고요'),
#  '늘': ('늘', ''),
#  '구매해': ('구매', '해'),
#  '구매해서': ('구매', '해서'),
#  '쓰': ('쓰', ''),
#  '쓰고': ('쓰고', ''),
#  '있는데': ('있는', '데'),
#  '이번꺼': ('이번', '꺼'),
#  '이번꺼도': ('이번', '꺼도'),
#  '좋네': ('좋네', ''),
#  '좋네요': ('좋네', '요'),
#  '피': ('피', ''),
#  '피부': ('피부', ''),
#  '피부도': ('피부', '도'),
#  '좋아보': ('좋아', '보'),
#  '좋아보이': ('좋아', '보이'),
#  '좋아보이고': ('좋아', '보이고'),
#  '젊어': ('젊어', ''),
#  '젊어보': ('젊어', '보'),
#  '젊어보인': ('젊어', '보인'),
#  '젊어보인다': ('젊어', '보인다'),
#  '젊어보인다네': ('젊어', '보인다네'),
#  '젊어보인다네요': ('젊어', '보인다네요'),
#  '젊어보인다네요ㅎ': ('젊어', '보인다네요ㅎ'),
#  '노': ('노', ''),
#  '노와': ('노와', ''),
#  '노와이': ('노와', '이'),
#  '노와이이': ('노와', '이이'),
#  '노와이이에': ('노와', '이이에'),
#  '레': ('레', ''),
#  '레이': ('레이', ''),
#  '레이스': ('레이', '스'),
#  '달': ('달', ''),
#  '달린': ('달린', ''),
#  '브': ('브', ''),
#  '브랜': ('브랜', ''),
#  '브랜드': ('브랜', '드'),
#  '브랜드를': ('브랜', '드를'),
#  '입었': ('입었', ''),
#  '입었었': ('입었', '었'),
#  '입었었는': ('입었', '었는'),
#  '입었었는데': ('입었', '었는데'),
#  '세탁': ('세탁', ''),
#  '세탁망': ('세탁', '망'),
#  '세탁망에': ('세탁', '망에'),
#  '넣': ('넣', ''),
#  '넣고': ('넣고', ''),
#  '빨아도': ('빨아', '도'),
#  '망': ('망', ''),
#  '망가': ('망가', ''),
#  '망가지': ('망가', '지'),
#  '망가지는': ('망가', '지는'),
#  '망가지는건': ('망가', '지는건'),
#  '어쩔': ('어쩔', ''),
#  '어쩔수': ('어쩔', '수'),
#  '어쩔수없': ('어쩔', '수없'),
#  '어쩔수없더': ('어쩔', '수없더'),
#  '어쩔수없더라': ('어쩔', '수없더라'),
#  '어쩔수없더라구': ('어쩔', '수없더라구'),
#  '어쩔수없더라구요': ('어쩔', '수없더라구요'),
#  '속옷도': ('속옷', '도'),
#  '년': ('년', ''),
#  '년에': ('년에', ''),
#  '한': ('한', ''),
#  '한번': ('한번', ''),
#  '한번인': ('한번', '인'),
#  '한번인가': ('한번', '인가'),
#  '교체': ('교체', ''),
#  '교체해': ('교체', '해'),
#  '교체해서': ('교체', '해서'),
#  '입는': ('입는', ''),
#  '입는게': ('입는', '게'),
#  '위생': ('위생', ''),
#  '위생적': ('위생', '적'),
#  '위생적이': ('위생', '적이'),
#  '위생적이라': ('위생', '적이라'),
#  '위생적이라는': ('위생', '적이라는'),
#  '말': ('말', ''),
#  '말을': ('말을', ''),
#  '들어서': ('들어', '서'),
#  '남편': ('남편', ''),
#  '남편따': ('남편', '따'),
#  '남편따라': ('남편', '따라'),
#  '구매했': ('구매', '했'),
#  '구매했어': ('구매', '했어'),
#  '구매했어요': ('구매', '했어요'),
#  '특': ('특', ''),
#  '특유': ('특유', ''),
#  '특유의': ('특유', '의'),
#  '화려': ('화려', ''),
#  '화려한': ('화려', '한'),
#  '맛': ('맛', ''),
#  '맛보': ('맛보', ''),
#  '맛보다': ('맛보', '다'),
#  '맛보다는': ('맛보', '다는'),
#  '담': ('담', ''),
#  '담백': ('담백', ''),
#  '담백한': ('담백', '한'),
#  '담백한맛': ('담백', '한맛'),
#  '담백한맛이': ('담백', '한맛이'),
#  '담백한맛이라': ('담백', '한맛이라'),
#  '좋았': ('좋았', ''),
#  '좋았구': ('좋았', '구'),
#  '좋았구요': ('좋았', '구요'),
#  '그': ('그', ''),
#  '이외': ('이외', ''),
#  '내구': ('내구', ''),
#  '내구성': ('내구', '성'),
#  '기능': ('기능', ''),
#  '기능성': ('기능', '성'),
#  '맘': ('맘', ''),
#  '맘에': ('맘에', ''),
#  '들어요': ('들어', '요'),
#  '예': ('예', ''),
#  '예전': ('예전', ''),
#  '예전에': ('예전', '에'),
#  '나왔': ('나왔', ''),
#  '나왔던': ('나왔', '던'),
#  '스': ('스', ''),
#  '스표': ('스표', ''),
#  '스표츠': ('스표츠', ''),
#  '스표츠브': ('스표츠브', ''),
#  '스표츠브라': ('스표츠브라', ''),
#  '스표츠브라의': ('스표츠브라의', ''),
#  '투': ('투', ''),
#  '투박': ('투박', ''),
#  '투박함': ('투박', '함'),
#  '투박함이': ('투박', '함이'),
#  '투박함이없': ('투박', '함이없'),
#  '투박함이없어': ('투박', '함이없어'),
#  '투박함이없어서': ('투박', '함이없어서'),
#  '저렴하고': ('저렴', '하고'),
#  '접': ('접', ''),
#  '접었': ('접었', ''),
#  '접었을': ('접었', '을'),
#  '접었을때': ('접었', '을때'),
#  '보이': ('보이', ''),
#  '보이는': ('보이', '는'),
#  '밑': ('밑', ''),
#  '밑단': ('밑단', ''),
#  '밑단이': ('밑단', '이'),
#  '파': ('파', ''),
#  '파래': ('파래', ''),
#  '파래서': ('파래서', ''),
#  '이뻐': ('이뻐', ''),
#  '이뻐요': ('이뻐', '요'),
#  '기모': ('기모', ''),
#  '기모도': ('기모', '도'),
#  '도': ('도', ''),
#  '도톰': ('도톰', ''),
#  '도톰하': ('도톰', '하'),
#  '도톰하구': ('도톰', '하구'),
#  '도톰하구요': ('도톰', '하구요'),
#  '만족요': ('만족', '요'),
#  '몇': ('몇', ''),
#  '몇년': ('몇년', ''),
#  '몇년동': ('몇년', '동'),
#  '몇년동안': ('몇년', '동안'),
#  '사용하던': ('사용', '하던'),
#  '사용하던거': ('사용', '하던거'),
#  '사용하던거라': ('사용', '하던거라'),
#  '믿': ('믿', ''),
#  '믿고': ('믿고', ''),
#  '구매했습': ('구매', '했습'),
#  '구매했습니': ('구매', '했습니'),
#  ...}
